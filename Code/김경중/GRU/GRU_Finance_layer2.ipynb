# %%
# !pip install -U finance-datareader
# !pip install torch torchvision
# Out:
# Collecting finance-datareader
#   Downloading https://files.pythonhosted.org/packages/2a/46/4e398780dfb1af6dba7b4ee8b440829b65e94b2726f1d2cc13015d41d172/finance_datareader-0.9.6-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from finance-datareader) (2.23.0)
# Requirement already satisfied, skipping upgrade: lxml in /usr/local/lib/python3.6/dist-packages (from finance-datareader) (4.2.6)
# Collecting requests-file
#   Downloading https://files.pythonhosted.org/packages/77/86/cdb5e8eaed90796aa83a6d9f75cfbd37af553c47a291cd47bc410ef9bdb2/requests_file-1.5.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from finance-datareader) (1.0.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from requests-file->finance-datareader) (1.15.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->finance-datareader) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->finance-datareader) (1.18.5)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.6 requests-file-1.5.1
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.7.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (7.0.0)

# %%
import pandas as pd
import pandas_datareader as pdr
import FinanceDataReader as fdr
import datetime
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
import argparse
import time
from copy import deepcopy # Add Deepcopy for args
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# %matplotlib inline
#데이터 생성과 화면 표시를 위한 라이브러리 호출
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
'''import FinanceDataReader as fdr

# 한국거래소 상장종목 전체
df_krx = fdr.StockListing('KRX')
df_krx.head()'''
# Out:
# "import FinanceDataReader as fdr\n\n# 한국거래소 상장종목 전체\ndf_krx = fdr.StockListing('KRX')\ndf_krx.head()"

# %%
class StockDataset(Dataset):
    
    def __init__(self, symbol, x_frames, y_frames, start, end):
        
        self.symbol = symbol
        self.x_frames = x_frames
        self.y_frames = y_frames
        
        self.start = datetime.datetime(*start)
        self.end = datetime.datetime(*end)
        self.scaler = MinMaxScaler()
        self.data = fdr.DataReader(self.symbol, self.start, self.end)#주식 6가지 특징, 고,시,저,종,거,변
        df_gold = pdr.DataReader('GOLDAMGBD228NLBM', 'fred', start=self.start, end=self.end)#금값
        df_du = pdr.DataReader('POILDUBUSDM', 'fred', start=self.start, end=self.end)#석유
        df_kospi = fdr.DataReader('KS11', self.start, self.end)#코스피
        df_dollar = fdr.DataReader('USD/KRW', self.start, self.end)#원달러환율

        #gold 채우기
        df_gold = df_gold.fillna(value=-1)
        gold = []
        for i in df_gold.values:
            gold.append(i[0])

        check = min(gold)
        for i in range(0,len(gold)):
            if gold[i] == -1:
                gold[i] = check
            else:
                check = gold[i]
        #oil 채우기
        du = df_du.values
        ddu = []
        check = int(list(start)[1])
        c = 0
        for i in self.data.index:
            if i.month == check:
                ddu.append(du[c][0])
            else:
                check += 1
                if check >= 13:
                    check = 1
                c += 1
                if c >= len(du):
                    break
                ddu.append(du[c][0])
        
        self.data['dollar'] = df_dollar[['Close']]
        self.data['kospi'] = df_kospi[['Close']]
        self.data['oil'] = pd.DataFrame(data=ddu, index=self.data.index, columns=['oil'])
        self.data['gold'] = pd.DataFrame(data=gold, index=df_gold.index, columns=['gold'])
        print('len:',len(self.data.index))
        self.data = pd.DataFrame(self.scaler.fit_transform(self.data))
        
    def __len__(self):
        return len(self.data) - (self.x_frames + self.y_frames) + 1
    
    def __getitem__(self, idx):
        idx += self.x_frames
        data = self.data.iloc[idx-self.x_frames:idx+self.y_frames]
        #data = data.apply(lambda x: x//10000)
        data = data.values
        X = data[:self.x_frames]
        y = data[self.x_frames:]
        
        return X, y

# %%
class GRU(nn.Module):
    
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers, batch_size, dropout, use_bn):
        super(GRU, self).__init__()
        self.input_dim = input_dim 
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.num_layers = num_layers

        self.batch_size = batch_size
        self.dropout = dropout
        self.use_bn = use_bn 
        self.norm =nn.BatchNorm1d(self.batch_size)
        self.gru = nn.GRU(self.input_dim, self.hidden_dim*2, self.num_layers)
        self.gru2 = nn.GRU(self.hidden_dim*2, self.hidden_dim, self.num_layers)
        self.regressor = self.make_regressor()

    def make_regressor(self):
        layers = []
        if self.use_bn:
            layers.append(nn.BatchNorm1d(self.hidden_dim))
        layers.append(nn.Dropout(self.dropout))
        
        layers.append(nn.Linear(self.hidden_dim, self.hidden_dim//2))
        layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim//2, self.output_dim))
        regressor = nn.Sequential(*layers)
        return regressor
    
    def forward(self, x):
        x, _ = self.gru(x)
        x, _ = self.gru2(x)
        y_pred = self.regressor(x[-1].view(self.batch_size, -1))
        return y_pred

# %%
def metric(y_pred, y_true):
    perc_y_pred = np.exp(y_pred.cpu().detach().numpy())
    perc_y_true = np.exp(y_true.cpu().detach().numpy())
    mae = mean_absolute_error(perc_y_true, perc_y_pred, multioutput='raw_values')
    return mae*100

# %%
def train(model, trainset, optimizer, loss_fn, args):
    trainloader = DataLoader(trainset, 
                             batch_size=args.batch_size, 
                             shuffle=True, drop_last=True)
    model.train()
    model.zero_grad()
    optimizer.zero_grad()

    train_acc = 0.0
    train_loss = 0.0
    for i, (X, y) in enumerate(trainloader):

        X = X.transpose(0, 1).float().to(args.device)
        y_true = y[:, :, 3].float().to(args.device)
        #print(torch.max(X[:, :, 3]), torch.max(y_true))

        model.zero_grad()
        optimizer.zero_grad()

        y_pred = model(X)
        loss = loss_fn(y_pred.view(-1), y_true.view(-1))
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_acc += metric(y_pred, y_true)[0]

    train_loss = train_loss / len(trainloader)
    train_acc = train_acc / len(trainloader)
    return model, train_loss, train_acc

# %%
def validate(model, valset, loss_fn, args):
    valloader = DataLoader(valset, 
                           batch_size=args.batch_size, 
                           shuffle=False, drop_last=True)
    model.eval()

    val_acc = 0.0
    val_loss = 0.0
    with torch.no_grad():
        for i, (X, y) in enumerate(valloader):

            X = X.transpose(0, 1).float().to(args.device)
            y_true = y[:, :, 3].float().to(args.device)

            y_pred = model(X)
            loss = loss_fn(y_pred.view(-1), y_true.view(-1))

            val_loss += loss.item()
            val_acc += metric(y_pred, y_true)[0]
    val_loss = val_loss / len(valloader)
    val_acc = val_acc / len(valloader)
    return val_loss, val_acc

# %%
def experiment(trainset,valset, model,args,min_val):

    model.to(args.device)
    loss_fn = torch.nn.MSELoss()

    loss_fn = nn.MSELoss()
    if args.optim == 'SGD':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')
    
    # ===== List for epoch-wise data ====== #
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
    # ===================================== #
        
    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        model, train_loss, train_acc = train(model, trainset, optimizer, loss_fn, args)
        val_loss, val_acc = validate(model, valset, loss_fn, args)
        te = time.time()
        if val_acc < min_val:
            min_val = val_acc
            torch.save(model.state_dict(), '/content/gdrive/My Drive/GRUmodel/GRU_Best_model.pt')
            print('Best model saved')
        
        # ====== Add Epoch Data ====== #
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        # ============================ #
        
        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.5f}/{:2.5f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))
        
    # ======= Add Result to Dictionary ======= #
    result = {}
    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['train_acc'] = train_acc
    result['val_acc'] = val_acc
    return vars(args), result, min_val

# %%
# ====== Random Seed Initialization ====== #
seed = 666
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ====== Data Loading ====== #
#삼성전자,Sk하이닉스,네이버,LG화학,셀트리온,현대차,카카오,삼성SDI,LG생활건강,현대모비스
#SK텔레콤,NC소프트,기아차,포스코,KB금융,SK,LG전자,LG,한국전력,삼성생명
args.symbol = ['005930','000660','035420','051910','068270','005380','035720','006400','051900','012330',
               '017670','036570','000270','005490','105560','034730','066570','003550','015760']#,'032830']
args.batch_size = 128
args.x_frames = 7
args.y_frames = 7

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# ====== Model Capacity ===== #
args.input_dim = 10
args.hid_dim = 64
args.n_layers = 2

# ====== Regularization ======= #
args.l2 = 0.00001
args.dropout = 0.3
args.use_bn = True

# ====== Optimizer & Training ====== #
args.optim = 'Adam' #'RMSprop' #SGD, RMSprop, ADAM...
args.lr = 0.001
args.epoch = 30


model = GRU(args.input_dim, args.hid_dim, args.y_frames, args.n_layers, args.batch_size, args.dropout, args.use_bn)
best_model = GRU(args.input_dim, args.hid_dim, args.y_frames, args.n_layers, args.batch_size, args.dropout, args.use_bn)
min_val = 100
print(args)

valset = StockDataset('028050', args.x_frames,args.y_frames,(2011,1,1), (2020,1,1))

for sb in args.symbol:
    trainset = StockDataset(sb, args.x_frames,args.y_frames,(2011,1,1), (2020,1,1))    
    setting, result,min_val = experiment(trainset, valset, model,deepcopy(args),min_val)
# Out:
# Namespace(batch_size=128, device='cuda', dropout=0.3, epoch=30, hid_dim=64, input_dim=10, l2=1e-05, lr=0.001, n_layers=2, optim='Adam', symbol=['005930', '000660', '035420', '051910', '068270', '005380', '035720', '006400', '051900', '012330', '017670', '036570', '000270', '005490', '105560', '034730', '066570', '003550', '015760'], use_bn=True, x_frames=7, y_frames=7)
# len: 2215
# len: 2215
# Best model saved
# Epoch 0, Acc(train/val): 36.07/29.22, Loss(train/val) 0.15547/0.10589. Took 0.54 sec
# Best model saved
# Epoch 1, Acc(train/val): 23.34/24.79, Loss(train/val) 0.04143/0.07871. Took 0.55 sec
# Best model saved
# Epoch 2, Acc(train/val): 19.97/22.53, Loss(train/val) 0.02526/0.04737. Took 0.55 sec
# Best model saved
# Epoch 3, Acc(train/val): 17.75/10.88, Loss(train/val) 0.01974/0.01628. Took 0.55 sec
# Epoch 4, Acc(train/val): 16.47/17.90, Loss(train/val) 0.01704/0.02599. Took 0.54 sec
# Epoch 5, Acc(train/val): 14.73/24.57, Loss(train/val) 0.01476/0.04075. Took 0.54 sec
# Epoch 6, Acc(train/val): 13.56/13.18, Loss(train/val) 0.01255/0.03132. Took 0.54 sec
# Epoch 7, Acc(train/val): 12.40/16.30, Loss(train/val) 0.01123/0.03260. Took 0.54 sec
# Epoch 8, Acc(train/val): 12.04/21.34, Loss(train/val) 0.01030/0.02289. Took 0.55 sec
# Epoch 9, Acc(train/val): 11.34/20.36, Loss(train/val) 0.00976/0.04182. Took 0.55 sec
# Epoch 10, Acc(train/val): 10.65/21.46, Loss(train/val) 0.00867/0.03253. Took 0.54 sec
# Epoch 11, Acc(train/val): 10.23/12.77, Loss(train/val) 0.00759/0.02317. Took 0.54 sec
# Epoch 12, Acc(train/val): 10.11/14.07, Loss(train/val) 0.00737/0.02381. Took 0.55 sec
# Epoch 13, Acc(train/val): 10.08/11.89, Loss(train/val) 0.00757/0.01814. Took 0.57 sec
# Epoch 14, Acc(train/val): 9.99/16.15, Loss(train/val) 0.00689/0.02165. Took 0.54 sec
# Epoch 15, Acc(train/val): 8.50/15.94, Loss(train/val) 0.00549/0.01598. Took 0.55 sec
# Epoch 16, Acc(train/val): 9.46/15.17, Loss(train/val) 0.00676/0.01287. Took 0.54 sec
# Epoch 17, Acc(train/val): 8.51/13.00, Loss(train/val) 0.00559/0.01115. Took 0.53 sec
# Epoch 18, Acc(train/val): 8.32/14.64, Loss(train/val) 0.00522/0.00963. Took 0.54 sec
# Epoch 19, Acc(train/val): 8.23/11.95, Loss(train/val) 0.00513/0.01063. Took 0.55 sec
# Epoch 20, Acc(train/val): 8.42/16.88, Loss(train/val) 0.00531/0.01801. Took 0.54 sec
# Best model saved
# Epoch 21, Acc(train/val): 8.91/9.87, Loss(train/val) 0.00582/0.00824. Took 0.56 sec
# Best model saved
# Epoch 22, Acc(train/val): 7.99/9.28, Loss(train/val) 0.00490/0.00585. Took 0.54 sec
# Epoch 23, Acc(train/val): 7.75/11.55, Loss(train/val) 0.00441/0.00888. Took 0.54 sec
# Best model saved
# Epoch 24, Acc(train/val): 8.23/8.15, Loss(train/val) 0.00474/0.00520. Took 0.54 sec
# Epoch 25, Acc(train/val): 7.57/8.28, Loss(train/val) 0.00424/0.00765. Took 0.54 sec
# Best model saved
# Epoch 26, Acc(train/val): 7.40/7.34, Loss(train/val) 0.00420/0.00697. Took 0.54 sec
# Epoch 27, Acc(train/val): 7.89/9.85, Loss(train/val) 0.00464/0.00720. Took 0.54 sec
# Best model saved
# Epoch 28, Acc(train/val): 7.71/7.16, Loss(train/val) 0.00423/0.00589. Took 0.54 sec
# Epoch 29, Acc(train/val): 7.08/7.24, Loss(train/val) 0.00386/0.00769. Took 0.53 sec
# len: 2215
# Best model saved
# Epoch 0, Acc(train/val): 10.62/4.37, Loss(train/val) 0.00789/0.00410. Took 0.55 sec
# Epoch 1, Acc(train/val): 7.90/6.23, Loss(train/val) 0.00458/0.00568. Took 0.54 sec
# Epoch 2, Acc(train/val): 7.46/6.00, Loss(train/val) 0.00418/0.00397. Took 0.56 sec
# Epoch 3, Acc(train/val): 6.61/10.55, Loss(train/val) 0.00352/0.00708. Took 0.53 sec
# Epoch 4, Acc(train/val): 6.24/4.95, Loss(train/val) 0.00328/0.00360. Took 0.54 sec
# Epoch 5, Acc(train/val): 6.57/7.73, Loss(train/val) 0.00349/0.00443. Took 0.55 sec
# Epoch 6, Acc(train/val): 6.93/7.97, Loss(train/val) 0.00389/0.00483. Took 0.54 sec
# Epoch 7, Acc(train/val): 6.30/5.79, Loss(train/val) 0.00325/0.00281. Took 0.54 sec
# Epoch 8, Acc(train/val): 6.09/7.47, Loss(train/val) 0.00315/0.00408. Took 0.54 sec
# Epoch 9, Acc(train/val): 5.87/4.78, Loss(train/val) 0.00293/0.00304. Took 0.54 sec
# Epoch 10, Acc(train/val): 6.05/4.82, Loss(train/val) 0.00314/0.00306. Took 0.55 sec
# Best model saved
# Epoch 11, Acc(train/val): 6.57/3.98, Loss(train/val) 0.00353/0.00178. Took 0.56 sec
# Epoch 12, Acc(train/val): 6.74/8.54, Loss(train/val) 0.00389/0.00581. Took 0.53 sec
# Epoch 13, Acc(train/val): 6.92/7.15, Loss(train/val) 0.00351/0.00383. Took 0.54 sec
# Epoch 14, Acc(train/val): 6.57/8.28, Loss(train/val) 0.00322/0.00530. Took 0.53 sec
# Epoch 15, Acc(train/val): 5.14/9.78, Loss(train/val) 0.00249/0.00616. Took 0.54 sec
# Epoch 16, Acc(train/val): 5.78/5.63, Loss(train/val) 0.00310/0.00279. Took 0.53 sec
# Epoch 17, Acc(train/val): 5.70/4.31, Loss(train/val) 0.00272/0.00182. Took 0.55 sec
# Epoch 18, Acc(train/val): 5.39/8.05, Loss(train/val) 0.00255/0.00469. Took 0.53 sec
# Epoch 19, Acc(train/val): 5.89/4.07, Loss(train/val) 0.00289/0.00185. Took 0.54 sec
# Epoch 20, Acc(train/val): 6.37/5.17, Loss(train/val) 0.00321/0.00203. Took 0.53 sec
# Epoch 21, Acc(train/val): 5.07/4.52, Loss(train/val) 0.00237/0.00219. Took 0.55 sec
# Epoch 22, Acc(train/val): 4.94/6.81, Loss(train/val) 0.00228/0.00342. Took 0.54 sec
# Epoch 23, Acc(train/val): 5.88/7.24, Loss(train/val) 0.00309/0.00299. Took 0.54 sec
# Epoch 24, Acc(train/val): 5.75/6.92, Loss(train/val) 0.00279/0.00396. Took 0.54 sec
# Best model saved
# Epoch 25, Acc(train/val): 5.24/3.17, Loss(train/val) 0.00262/0.00137. Took 0.54 sec
# Epoch 26, Acc(train/val): 4.72/4.89, Loss(train/val) 0.00204/0.00220. Took 0.53 sec
# Epoch 27, Acc(train/val): 4.97/3.68, Loss(train/val) 0.00219/0.00161. Took 0.53 sec
# Epoch 28, Acc(train/val): 6.03/6.34, Loss(train/val) 0.00293/0.00257. Took 0.54 sec
# Epoch 29, Acc(train/val): 7.22/8.44, Loss(train/val) 0.00375/0.00626. Took 0.54 sec
# len: 2215
# Epoch 0, Acc(train/val): 10.81/14.12, Loss(train/val) 0.00717/0.01361. Took 0.54 sec
# Epoch 1, Acc(train/val): 7.55/7.95, Loss(train/val) 0.00409/0.00408. Took 0.53 sec
# Epoch 2, Acc(train/val): 7.58/15.39, Loss(train/val) 0.00385/0.01294. Took 0.55 sec
# Epoch 3, Acc(train/val): 7.76/7.87, Loss(train/val) 0.00379/0.00299. Took 0.56 sec
# Epoch 4, Acc(train/val): 7.93/14.17, Loss(train/val) 0.00418/0.01239. Took 0.52 sec
# Epoch 5, Acc(train/val): 7.33/11.69, Loss(train/val) 0.00359/0.00626. Took 0.53 sec
# Epoch 6, Acc(train/val): 8.31/13.84, Loss(train/val) 0.00433/0.01068. Took 0.52 sec
# Epoch 7, Acc(train/val): 7.72/9.52, Loss(train/val) 0.00386/0.00604. Took 0.53 sec
# Epoch 8, Acc(train/val): 6.40/3.72, Loss(train/val) 0.00303/0.00178. Took 0.53 sec
# Epoch 9, Acc(train/val): 6.74/15.37, Loss(train/val) 0.00320/0.01183. Took 0.55 sec
# Epoch 10, Acc(train/val): 6.58/6.96, Loss(train/val) 0.00313/0.00398. Took 0.53 sec
# Epoch 11, Acc(train/val): 8.62/15.97, Loss(train/val) 0.00491/0.01290. Took 0.54 sec
# Epoch 12, Acc(train/val): 7.15/15.01, Loss(train/val) 0.00346/0.01427. Took 0.52 sec
# Epoch 13, Acc(train/val): 7.68/6.98, Loss(train/val) 0.00388/0.00260. Took 0.55 sec
# Epoch 14, Acc(train/val): 6.44/5.10, Loss(train/val) 0.00292/0.00263. Took 0.54 sec
# Epoch 15, Acc(train/val): 7.41/11.76, Loss(train/val) 0.00359/0.00712. Took 0.55 sec
# Epoch 16, Acc(train/val): 6.45/11.94, Loss(train/val) 0.00319/0.00700. Took 0.54 sec
# Epoch 17, Acc(train/val): 7.25/10.87, Loss(train/val) 0.00314/0.00698. Took 0.54 sec
# Epoch 18, Acc(train/val): 6.41/10.90, Loss(train/val) 0.00318/0.00823. Took 0.53 sec
# Epoch 19, Acc(train/val): 5.90/7.73, Loss(train/val) 0.00262/0.00532. Took 0.54 sec
# Epoch 20, Acc(train/val): 5.41/12.39, Loss(train/val) 0.00242/0.00986. Took 0.54 sec
# Epoch 21, Acc(train/val): 6.39/14.24, Loss(train/val) 0.00289/0.01429. Took 0.54 sec
# Epoch 22, Acc(train/val): 6.50/6.01, Loss(train/val) 0.00301/0.00413. Took 0.52 sec
# Epoch 23, Acc(train/val): 6.12/6.45, Loss(train/val) 0.00269/0.00363. Took 0.53 sec
# Epoch 24, Acc(train/val): 6.00/8.33, Loss(train/val) 0.00272/0.00732. Took 0.54 sec
# Epoch 25, Acc(train/val): 6.24/7.53, Loss(train/val) 0.00260/0.00370. Took 0.54 sec
# Epoch 26, Acc(train/val): 5.81/6.43, Loss(train/val) 0.00261/0.00374. Took 0.55 sec
# Epoch 27, Acc(train/val): 5.15/10.83, Loss(train/val) 0.00216/0.00732. Took 0.53 sec
# Epoch 28, Acc(train/val): 6.96/7.63, Loss(train/val) 0.00308/0.00374. Took 0.54 sec
# Epoch 29, Acc(train/val): 5.95/9.59, Loss(train/val) 0.00271/0.00561. Took 0.54 sec
# len: 2215
# Epoch 0, Acc(train/val): 9.22/7.98, Loss(train/val) 0.00854/0.00479. Took 0.54 sec
# Epoch 1, Acc(train/val): 4.88/9.73, Loss(train/val) 0.00260/0.01092. Took 0.53 sec
# Best model saved
# Epoch 2, Acc(train/val): 4.18/2.12, Loss(train/val) 0.00214/0.00134. Took 0.54 sec
# Epoch 3, Acc(train/val): 3.89/3.30, Loss(train/val) 0.00216/0.00089. Took 0.53 sec
# Epoch 4, Acc(train/val): 3.76/2.36, Loss(train/val) 0.00197/0.00082. Took 0.56 sec
# Epoch 5, Acc(train/val): 3.86/12.82, Loss(train/val) 0.00194/0.00930. Took 0.53 sec
# Epoch 6, Acc(train/val): 3.83/5.96, Loss(train/val) 0.00189/0.00224. Took 0.54 sec
# Epoch 7, Acc(train/val): 3.82/4.76, Loss(train/val) 0.00191/0.00160. Took 0.53 sec
# Epoch 8, Acc(train/val): 3.74/7.08, Loss(train/val) 0.00188/0.00281. Took 0.55 sec
# Epoch 9, Acc(train/val): 3.98/4.05, Loss(train/val) 0.00218/0.00213. Took 0.54 sec
# Epoch 10, Acc(train/val): 3.89/11.42, Loss(train/val) 0.00207/0.00680. Took 0.54 sec
# Epoch 11, Acc(train/val): 4.00/14.89, Loss(train/val) 0.00196/0.01261. Took 0.53 sec
# Epoch 12, Acc(train/val): 4.17/4.69, Loss(train/val) 0.00205/0.00215. Took 0.54 sec
# Epoch 13, Acc(train/val): 3.47/6.86, Loss(train/val) 0.00172/0.00349. Took 0.52 sec
# Epoch 14, Acc(train/val): 4.08/4.65, Loss(train/val) 0.00205/0.00211. Took 0.53 sec
# Epoch 15, Acc(train/val): 3.88/13.88, Loss(train/val) 0.00197/0.00966. Took 0.53 sec
# Epoch 16, Acc(train/val): 4.02/6.11, Loss(train/val) 0.00222/0.00389. Took 0.53 sec
# Epoch 17, Acc(train/val): 3.76/4.42, Loss(train/val) 0.00180/0.00101. Took 0.53 sec
# Epoch 18, Acc(train/val): 3.99/10.77, Loss(train/val) 0.00194/0.00846. Took 0.55 sec
# Epoch 19, Acc(train/val): 4.13/3.73, Loss(train/val) 0.00202/0.00104. Took 0.55 sec
# Epoch 20, Acc(train/val): 3.58/11.89, Loss(train/val) 0.00181/0.00858. Took 0.56 sec
# Epoch 21, Acc(train/val): 3.69/12.44, Loss(train/val) 0.00189/0.00831. Took 0.55 sec
# Epoch 22, Acc(train/val): 3.72/6.05, Loss(train/val) 0.00182/0.00218. Took 0.54 sec
# Epoch 23, Acc(train/val): 4.17/10.42, Loss(train/val) 0.00202/0.00749. Took 0.55 sec
# Epoch 24, Acc(train/val): 3.60/5.29, Loss(train/val) 0.00177/0.00205. Took 0.53 sec
# Epoch 25, Acc(train/val): 3.66/10.16, Loss(train/val) 0.00188/0.00632. Took 0.55 sec
# Epoch 26, Acc(train/val): 3.41/3.93, Loss(train/val) 0.00169/0.00147. Took 0.55 sec
# Epoch 27, Acc(train/val): 3.33/7.04, Loss(train/val) 0.00173/0.00224. Took 0.55 sec
# Epoch 28, Acc(train/val): 3.49/3.52, Loss(train/val) 0.00170/0.00167. Took 0.54 sec
# Epoch 29, Acc(train/val): 4.30/8.12, Loss(train/val) 0.00228/0.00342. Took 0.56 sec
# len: 2215
# Epoch 0, Acc(train/val): 10.74/13.75, Loss(train/val) 0.00933/0.02241. Took 0.52 sec
# Epoch 1, Acc(train/val): 4.75/17.94, Loss(train/val) 0.00269/0.01464. Took 0.55 sec
# Epoch 2, Acc(train/val): 3.82/7.47, Loss(train/val) 0.00181/0.00360. Took 0.53 sec
# Epoch 3, Acc(train/val): 3.66/2.94, Loss(train/val) 0.00162/0.00115. Took 0.53 sec
# Epoch 4, Acc(train/val): 4.43/5.80, Loss(train/val) 0.00211/0.00321. Took 0.53 sec
# Epoch 5, Acc(train/val): 3.69/3.25, Loss(train/val) 0.00172/0.00103. Took 0.53 sec
# Epoch 6, Acc(train/val): 3.76/2.88, Loss(train/val) 0.00175/0.00135. Took 0.52 sec
# Epoch 7, Acc(train/val): 4.97/5.28, Loss(train/val) 0.00253/0.00182. Took 0.53 sec
# Epoch 8, Acc(train/val): 3.58/4.38, Loss(train/val) 0.00161/0.00115. Took 0.54 sec
# Epoch 9, Acc(train/val): 4.09/9.02, Loss(train/val) 0.00199/0.00445. Took 0.52 sec
# Epoch 10, Acc(train/val): 5.67/10.75, Loss(train/val) 0.00356/0.00673. Took 0.53 sec
# Epoch 11, Acc(train/val): 3.65/6.69, Loss(train/val) 0.00169/0.00224. Took 0.52 sec
# Epoch 12, Acc(train/val): 4.13/6.42, Loss(train/val) 0.00204/0.00269. Took 0.53 sec
# Epoch 13, Acc(train/val): 4.74/7.28, Loss(train/val) 0.00254/0.00301. Took 0.52 sec
# Epoch 14, Acc(train/val): 4.47/3.78, Loss(train/val) 0.00211/0.00220. Took 0.52 sec
# Epoch 15, Acc(train/val): 3.68/10.27, Loss(train/val) 0.00166/0.00662. Took 0.52 sec
# Epoch 16, Acc(train/val): 4.00/5.47, Loss(train/val) 0.00197/0.00267. Took 0.54 sec
# Epoch 17, Acc(train/val): 3.68/3.21, Loss(train/val) 0.00182/0.00124. Took 0.52 sec
# Epoch 18, Acc(train/val): 3.86/2.36, Loss(train/val) 0.00178/0.00069. Took 0.54 sec
# Epoch 19, Acc(train/val): 4.21/4.34, Loss(train/val) 0.00204/0.00157. Took 0.55 sec
# Epoch 20, Acc(train/val): 4.14/2.70, Loss(train/val) 0.00208/0.00088. Took 0.53 sec
# Epoch 21, Acc(train/val): 3.51/6.41, Loss(train/val) 0.00151/0.00243. Took 0.52 sec
# Epoch 22, Acc(train/val): 3.49/2.81, Loss(train/val) 0.00158/0.00090. Took 0.54 sec
# Epoch 23, Acc(train/val): 4.07/4.34, Loss(train/val) 0.00187/0.00182. Took 0.53 sec
# Epoch 24, Acc(train/val): 3.36/6.77, Loss(train/val) 0.00146/0.00339. Took 0.53 sec
# Epoch 25, Acc(train/val): 4.01/3.50, Loss(train/val) 0.00193/0.00150. Took 0.54 sec
# Epoch 26, Acc(train/val): 3.90/7.22, Loss(train/val) 0.00182/0.00365. Took 0.53 sec
# Epoch 27, Acc(train/val): 3.90/4.23, Loss(train/val) 0.00189/0.00189. Took 0.54 sec
# Epoch 28, Acc(train/val): 3.35/4.77, Loss(train/val) 0.00146/0.00231. Took 0.53 sec
# Epoch 29, Acc(train/val): 3.90/3.23, Loss(train/val) 0.00199/0.00168. Took 0.54 sec
# len: 2215
# Epoch 0, Acc(train/val): 15.02/24.06, Loss(train/val) 0.01558/0.03403. Took 0.53 sec
# Epoch 1, Acc(train/val): 9.13/7.76, Loss(train/val) 0.00554/0.00290. Took 0.55 sec
# Epoch 2, Acc(train/val): 7.96/4.79, Loss(train/val) 0.00432/0.00297. Took 0.54 sec
# Epoch 3, Acc(train/val): 8.57/3.46, Loss(train/val) 0.00460/0.00103. Took 0.54 sec
# Epoch 4, Acc(train/val): 8.00/2.41, Loss(train/val) 0.00435/0.00079. Took 0.55 sec
# Epoch 5, Acc(train/val): 6.91/6.11, Loss(train/val) 0.00368/0.00345. Took 0.54 sec
# Epoch 6, Acc(train/val): 6.71/3.62, Loss(train/val) 0.00349/0.00121. Took 0.53 sec
# Epoch 7, Acc(train/val): 6.94/4.18, Loss(train/val) 0.00369/0.00148. Took 0.56 sec
# Epoch 8, Acc(train/val): 6.36/3.51, Loss(train/val) 0.00324/0.00126. Took 0.52 sec
# Epoch 9, Acc(train/val): 7.13/6.40, Loss(train/val) 0.00371/0.00229. Took 0.53 sec
# Epoch 10, Acc(train/val): 7.45/8.14, Loss(train/val) 0.00377/0.00495. Took 0.54 sec
# Epoch 11, Acc(train/val): 6.33/4.48, Loss(train/val) 0.00302/0.00170. Took 0.52 sec
# Epoch 12, Acc(train/val): 6.11/5.72, Loss(train/val) 0.00288/0.00261. Took 0.52 sec
# Epoch 13, Acc(train/val): 6.25/5.70, Loss(train/val) 0.00299/0.00210. Took 0.52 sec
# Epoch 14, Acc(train/val): 6.60/5.67, Loss(train/val) 0.00310/0.00171. Took 0.52 sec
# Best model saved
# Epoch 15, Acc(train/val): 6.45/2.11, Loss(train/val) 0.00317/0.00064. Took 0.52 sec
# Epoch 16, Acc(train/val): 5.90/5.44, Loss(train/val) 0.00276/0.00239. Took 0.53 sec
# Best model saved
# Epoch 17, Acc(train/val): 5.75/1.92, Loss(train/val) 0.00269/0.00065. Took 0.53 sec
# Epoch 18, Acc(train/val): 6.08/3.05, Loss(train/val) 0.00292/0.00088. Took 0.53 sec
# Epoch 19, Acc(train/val): 6.11/2.47, Loss(train/val) 0.00285/0.00087. Took 0.53 sec
# Epoch 20, Acc(train/val): 6.11/10.15, Loss(train/val) 0.00279/0.00597. Took 0.53 sec
# Epoch 21, Acc(train/val): 6.12/3.12, Loss(train/val) 0.00276/0.00101. Took 0.52 sec
# Epoch 22, Acc(train/val): 6.06/2.68, Loss(train/val) 0.00271/0.00136. Took 0.54 sec
# Epoch 23, Acc(train/val): 5.42/4.76, Loss(train/val) 0.00251/0.00148. Took 0.52 sec
# Epoch 24, Acc(train/val): 5.19/5.29, Loss(train/val) 0.00243/0.00218. Took 0.51 sec
# Epoch 25, Acc(train/val): 5.42/6.46, Loss(train/val) 0.00243/0.00326. Took 0.53 sec
# Epoch 26, Acc(train/val): 4.91/4.10, Loss(train/val) 0.00218/0.00128. Took 0.53 sec
# Epoch 27, Acc(train/val): 5.11/6.65, Loss(train/val) 0.00229/0.00267. Took 0.53 sec
# Epoch 28, Acc(train/val): 6.42/4.53, Loss(train/val) 0.00293/0.00138. Took 0.53 sec
# Epoch 29, Acc(train/val): 5.62/4.26, Loss(train/val) 0.00249/0.00139. Took 0.52 sec
# len: 2215
# Epoch 0, Acc(train/val): 6.45/12.43, Loss(train/val) 0.00468/0.00769. Took 0.52 sec
# Epoch 1, Acc(train/val): 4.60/13.74, Loss(train/val) 0.00328/0.01725. Took 0.53 sec
# Epoch 2, Acc(train/val): 4.79/12.15, Loss(train/val) 0.00340/0.01422. Took 0.52 sec
# Epoch 3, Acc(train/val): 4.48/15.73, Loss(train/val) 0.00331/0.01803. Took 0.53 sec
# Epoch 4, Acc(train/val): 4.96/9.83, Loss(train/val) 0.00347/0.00754. Took 0.52 sec
# Epoch 5, Acc(train/val): 5.10/17.30, Loss(train/val) 0.00347/0.01831. Took 0.54 sec
# Epoch 6, Acc(train/val): 4.61/10.69, Loss(train/val) 0.00329/0.01208. Took 0.52 sec
# Epoch 7, Acc(train/val): 4.41/21.63, Loss(train/val) 0.00325/0.03056. Took 0.52 sec
# Epoch 8, Acc(train/val): 4.95/8.68, Loss(train/val) 0.00339/0.00633. Took 0.52 sec
# Epoch 9, Acc(train/val): 5.24/16.43, Loss(train/val) 0.00360/0.01868. Took 0.53 sec
# Epoch 10, Acc(train/val): 5.05/19.49, Loss(train/val) 0.00345/0.02505. Took 0.52 sec
# Epoch 11, Acc(train/val): 4.47/10.46, Loss(train/val) 0.00333/0.00965. Took 0.54 sec
# Epoch 12, Acc(train/val): 4.80/15.67, Loss(train/val) 0.00353/0.01366. Took 0.52 sec
# Epoch 13, Acc(train/val): 4.55/13.61, Loss(train/val) 0.00329/0.01296. Took 0.53 sec
# Epoch 14, Acc(train/val): 5.48/11.50, Loss(train/val) 0.00352/0.01406. Took 0.54 sec
# Epoch 15, Acc(train/val): 5.84/18.33, Loss(train/val) 0.00377/0.02367. Took 0.52 sec
# Epoch 16, Acc(train/val): 4.24/10.48, Loss(train/val) 0.00304/0.01143. Took 0.53 sec
# Epoch 17, Acc(train/val): 4.21/12.94, Loss(train/val) 0.00301/0.01392. Took 0.53 sec
# Epoch 18, Acc(train/val): 4.12/12.40, Loss(train/val) 0.00296/0.01505. Took 0.52 sec
# Epoch 19, Acc(train/val): 4.67/9.32, Loss(train/val) 0.00311/0.00762. Took 0.54 sec
# Epoch 20, Acc(train/val): 5.10/15.28, Loss(train/val) 0.00357/0.01910. Took 0.53 sec
# Epoch 21, Acc(train/val): 4.18/14.29, Loss(train/val) 0.00304/0.01678. Took 0.53 sec
# Epoch 22, Acc(train/val): 4.39/14.37, Loss(train/val) 0.00307/0.00766. Took 0.54 sec
# Epoch 23, Acc(train/val): 4.68/16.56, Loss(train/val) 0.00326/0.01826. Took 0.53 sec
# Epoch 24, Acc(train/val): 4.63/13.32, Loss(train/val) 0.00317/0.01259. Took 0.53 sec
# Epoch 25, Acc(train/val): 4.51/13.27, Loss(train/val) 0.00324/0.01561. Took 0.52 sec
# Epoch 26, Acc(train/val): 5.00/12.85, Loss(train/val) 0.00325/0.01401. Took 0.52 sec
# Epoch 27, Acc(train/val): 5.56/17.59, Loss(train/val) 0.00369/0.01587. Took 0.52 sec
# Epoch 28, Acc(train/val): 5.13/18.85, Loss(train/val) 0.00332/0.02325. Took 0.52 sec
# Epoch 29, Acc(train/val): 4.43/11.58, Loss(train/val) 0.00310/0.00841. Took 0.51 sec
# len: 2215
# Epoch 0, Acc(train/val): 6.55/5.92, Loss(train/val) 0.00348/0.00229. Took 0.53 sec
# Epoch 1, Acc(train/val): 5.73/7.27, Loss(train/val) 0.00291/0.00387. Took 0.52 sec
# Epoch 2, Acc(train/val): 5.26/5.15, Loss(train/val) 0.00248/0.00271. Took 0.52 sec
# Epoch 3, Acc(train/val): 4.74/3.38, Loss(train/val) 0.00217/0.00101. Took 0.52 sec
# Epoch 4, Acc(train/val): 5.31/5.45, Loss(train/val) 0.00257/0.00247. Took 0.52 sec
# Epoch 5, Acc(train/val): 5.61/12.04, Loss(train/val) 0.00277/0.00906. Took 0.51 sec
# Epoch 6, Acc(train/val): 6.20/3.01, Loss(train/val) 0.00304/0.00180. Took 0.53 sec
# Epoch 7, Acc(train/val): 5.28/2.17, Loss(train/val) 0.00252/0.00058. Took 0.51 sec
# Epoch 8, Acc(train/val): 5.71/8.54, Loss(train/val) 0.00269/0.00475. Took 0.52 sec
# Epoch 9, Acc(train/val): 4.57/2.57, Loss(train/val) 0.00218/0.00098. Took 0.52 sec
# Epoch 10, Acc(train/val): 5.28/10.24, Loss(train/val) 0.00252/0.00660. Took 0.51 sec
# Best model saved
# Epoch 11, Acc(train/val): 4.50/1.81, Loss(train/val) 0.00212/0.00060. Took 0.52 sec
# Epoch 12, Acc(train/val): 5.51/3.46, Loss(train/val) 0.00255/0.00149. Took 0.51 sec
# Epoch 13, Acc(train/val): 5.25/6.76, Loss(train/val) 0.00230/0.00322. Took 0.52 sec
# Epoch 14, Acc(train/val): 5.08/11.44, Loss(train/val) 0.00241/0.00660. Took 0.53 sec
# Epoch 15, Acc(train/val): 5.07/6.01, Loss(train/val) 0.00233/0.00260. Took 0.52 sec
# Epoch 16, Acc(train/val): 6.41/3.08, Loss(train/val) 0.00289/0.00119. Took 0.52 sec
# Epoch 17, Acc(train/val): 5.75/6.78, Loss(train/val) 0.00245/0.00222. Took 0.52 sec
# Epoch 18, Acc(train/val): 4.63/1.86, Loss(train/val) 0.00212/0.00063. Took 0.52 sec
# Epoch 19, Acc(train/val): 5.52/13.88, Loss(train/val) 0.00271/0.01195. Took 0.52 sec
# Epoch 20, Acc(train/val): 5.99/2.26, Loss(train/val) 0.00266/0.00059. Took 0.53 sec
# Epoch 21, Acc(train/val): 4.77/2.61, Loss(train/val) 0.00223/0.00083. Took 0.52 sec
# Epoch 22, Acc(train/val): 4.95/7.10, Loss(train/val) 0.00235/0.00262. Took 0.52 sec
# Epoch 23, Acc(train/val): 4.70/9.19, Loss(train/val) 0.00220/0.00447. Took 0.52 sec
# Epoch 24, Acc(train/val): 4.75/2.51, Loss(train/val) 0.00244/0.00083. Took 0.52 sec
# Epoch 25, Acc(train/val): 4.99/9.96, Loss(train/val) 0.00233/0.00594. Took 0.51 sec
# Best model saved
# Epoch 26, Acc(train/val): 4.56/1.74, Loss(train/val) 0.00210/0.00059. Took 0.52 sec
# Epoch 27, Acc(train/val): 5.04/12.31, Loss(train/val) 0.00228/0.00819. Took 0.52 sec
# Epoch 28, Acc(train/val): 4.78/4.31, Loss(train/val) 0.00222/0.00216. Took 0.52 sec
# Epoch 29, Acc(train/val): 4.96/2.55, Loss(train/val) 0.00236/0.00070. Took 0.51 sec
# len: 2215
# Epoch 0, Acc(train/val): 7.17/11.05, Loss(train/val) 0.00324/0.00975. Took 0.53 sec
# Epoch 1, Acc(train/val): 4.73/6.23, Loss(train/val) 0.00190/0.00169. Took 0.51 sec
# Epoch 2, Acc(train/val): 4.61/4.37, Loss(train/val) 0.00197/0.00166. Took 0.51 sec
# Epoch 3, Acc(train/val): 5.39/20.03, Loss(train/val) 0.00217/0.01702. Took 0.52 sec
# Epoch 4, Acc(train/val): 6.58/12.65, Loss(train/val) 0.00283/0.01074. Took 0.50 sec
# Epoch 5, Acc(train/val): 5.06/3.49, Loss(train/val) 0.00198/0.00136. Took 0.52 sec
# Epoch 6, Acc(train/val): 5.53/3.34, Loss(train/val) 0.00220/0.00084. Took 0.59 sec
# Epoch 7, Acc(train/val): 4.20/8.35, Loss(train/val) 0.00156/0.00510. Took 0.53 sec
# Epoch 8, Acc(train/val): 4.26/2.34, Loss(train/val) 0.00166/0.00075. Took 0.51 sec
# Epoch 9, Acc(train/val): 4.49/2.60, Loss(train/val) 0.00177/0.00088. Took 0.52 sec
# Epoch 10, Acc(train/val): 4.70/6.28, Loss(train/val) 0.00184/0.00245. Took 0.50 sec
# Epoch 11, Acc(train/val): 4.57/5.16, Loss(train/val) 0.00169/0.00164. Took 0.52 sec
# Epoch 12, Acc(train/val): 5.35/13.62, Loss(train/val) 0.00198/0.00771. Took 0.51 sec
# Epoch 13, Acc(train/val): 5.13/1.77, Loss(train/val) 0.00192/0.00056. Took 0.52 sec
# Epoch 14, Acc(train/val): 4.94/2.51, Loss(train/val) 0.00189/0.00089. Took 0.50 sec
# Epoch 15, Acc(train/val): 5.83/9.25, Loss(train/val) 0.00246/0.00517. Took 0.52 sec
# Epoch 16, Acc(train/val): 5.18/4.31, Loss(train/val) 0.00203/0.00215. Took 0.51 sec
# Epoch 17, Acc(train/val): 5.02/2.15, Loss(train/val) 0.00213/0.00099. Took 0.52 sec
# Epoch 18, Acc(train/val): 4.83/2.40, Loss(train/val) 0.00182/0.00087. Took 0.51 sec
# Epoch 19, Acc(train/val): 4.63/2.32, Loss(train/val) 0.00209/0.00068. Took 0.53 sec
# Epoch 20, Acc(train/val): 4.63/4.25, Loss(train/val) 0.00191/0.00166. Took 0.51 sec
# Epoch 21, Acc(train/val): 5.06/15.99, Loss(train/val) 0.00196/0.01060. Took 0.51 sec
# Epoch 22, Acc(train/val): 4.68/2.02, Loss(train/val) 0.00187/0.00065. Took 0.52 sec
# Epoch 23, Acc(train/val): 4.45/8.11, Loss(train/val) 0.00167/0.00388. Took 0.52 sec
# Epoch 24, Acc(train/val): 5.08/1.96, Loss(train/val) 0.00205/0.00072. Took 0.50 sec
# Epoch 25, Acc(train/val): 4.40/3.05, Loss(train/val) 0.00168/0.00084. Took 0.52 sec
# Epoch 26, Acc(train/val): 4.70/2.75, Loss(train/val) 0.00186/0.00082. Took 0.51 sec
# Epoch 27, Acc(train/val): 5.03/7.44, Loss(train/val) 0.00212/0.00346. Took 0.54 sec
# Epoch 28, Acc(train/val): 5.22/8.66, Loss(train/val) 0.00238/0.00685. Took 0.51 sec
# Epoch 29, Acc(train/val): 5.42/2.08, Loss(train/val) 0.00216/0.00076. Took 0.52 sec
# len: 2215
# Epoch 0, Acc(train/val): 6.11/8.55, Loss(train/val) 0.00443/0.00710. Took 0.52 sec
# Epoch 1, Acc(train/val): 3.91/6.69, Loss(train/val) 0.00232/0.00272. Took 0.52 sec
# Epoch 2, Acc(train/val): 3.76/9.19, Loss(train/val) 0.00217/0.00465. Took 0.52 sec
# Epoch 3, Acc(train/val): 3.97/7.71, Loss(train/val) 0.00227/0.00404. Took 0.51 sec
# Epoch 4, Acc(train/val): 3.89/2.20, Loss(train/val) 0.00231/0.00069. Took 0.51 sec
# Epoch 5, Acc(train/val): 3.76/10.47, Loss(train/val) 0.00212/0.00611. Took 0.50 sec
# Epoch 6, Acc(train/val): 3.89/4.66, Loss(train/val) 0.00235/0.00118. Took 0.52 sec
# Epoch 7, Acc(train/val): 3.74/3.90, Loss(train/val) 0.00213/0.00175. Took 0.51 sec
# Epoch 8, Acc(train/val): 3.96/2.36, Loss(train/val) 0.00222/0.00083. Took 0.52 sec
# Epoch 9, Acc(train/val): 3.73/11.31, Loss(train/val) 0.00211/0.00809. Took 0.50 sec
# Epoch 10, Acc(train/val): 3.91/3.35, Loss(train/val) 0.00215/0.00096. Took 0.53 sec
# Epoch 11, Acc(train/val): 3.90/10.35, Loss(train/val) 0.00219/0.00458. Took 0.50 sec
# Epoch 12, Acc(train/val): 3.75/3.25, Loss(train/val) 0.00204/0.00084. Took 0.52 sec
# Epoch 13, Acc(train/val): 3.59/8.86, Loss(train/val) 0.00213/0.00483. Took 0.51 sec
# Epoch 14, Acc(train/val): 3.62/10.27, Loss(train/val) 0.00198/0.00630. Took 0.52 sec
# Epoch 15, Acc(train/val): 4.09/8.30, Loss(train/val) 0.00230/0.00432. Took 0.51 sec
# Epoch 16, Acc(train/val): 3.86/4.41, Loss(train/val) 0.00225/0.00083. Took 0.52 sec
# Epoch 17, Acc(train/val): 3.97/4.52, Loss(train/val) 0.00239/0.00288. Took 0.51 sec
# Epoch 18, Acc(train/val): 4.03/3.22, Loss(train/val) 0.00222/0.00069. Took 0.53 sec
# Epoch 19, Acc(train/val): 3.77/2.15, Loss(train/val) 0.00217/0.00136. Took 0.51 sec
# Epoch 20, Acc(train/val): 3.89/4.79, Loss(train/val) 0.00216/0.00187. Took 0.53 sec
# Epoch 21, Acc(train/val): 4.02/11.87, Loss(train/val) 0.00221/0.00847. Took 0.54 sec
# Epoch 22, Acc(train/val): 3.89/4.33, Loss(train/val) 0.00217/0.00164. Took 0.53 sec
# Epoch 23, Acc(train/val): 3.60/8.36, Loss(train/val) 0.00206/0.00429. Took 0.51 sec
# Epoch 24, Acc(train/val): 3.55/9.13, Loss(train/val) 0.00202/0.00426. Took 0.53 sec
# Epoch 25, Acc(train/val): 3.64/8.21, Loss(train/val) 0.00210/0.00362. Took 0.50 sec
# Epoch 26, Acc(train/val): 3.56/9.56, Loss(train/val) 0.00198/0.00483. Took 0.52 sec
# Epoch 27, Acc(train/val): 4.17/2.81, Loss(train/val) 0.00227/0.00084. Took 0.51 sec
# Epoch 28, Acc(train/val): 3.53/10.23, Loss(train/val) 0.00203/0.00664. Took 0.53 sec
# Epoch 29, Acc(train/val): 3.79/2.19, Loss(train/val) 0.00221/0.00070. Took 0.53 sec
# len: 2215
# Epoch 0, Acc(train/val): 15.31/47.48, Loss(train/val) 0.01199/0.08772. Took 0.52 sec
# Epoch 1, Acc(train/val): 7.69/3.35, Loss(train/val) 0.00329/0.00158. Took 0.51 sec
# Epoch 2, Acc(train/val): 7.12/7.99, Loss(train/val) 0.00302/0.00593. Took 0.53 sec
# Epoch 3, Acc(train/val): 6.45/5.39, Loss(train/val) 0.00273/0.00252. Took 0.53 sec
# Epoch 4, Acc(train/val): 5.65/2.68, Loss(train/val) 0.00241/0.00115. Took 0.53 sec
# Epoch 5, Acc(train/val): 6.31/7.11, Loss(train/val) 0.00266/0.00399. Took 0.51 sec
# Epoch 6, Acc(train/val): 5.78/4.34, Loss(train/val) 0.00234/0.00158. Took 0.53 sec
# Epoch 7, Acc(train/val): 5.16/6.26, Loss(train/val) 0.00207/0.00289. Took 0.53 sec
# Epoch 8, Acc(train/val): 5.85/5.17, Loss(train/val) 0.00249/0.00226. Took 0.53 sec
# Epoch 9, Acc(train/val): 5.66/5.36, Loss(train/val) 0.00221/0.00236. Took 0.53 sec
# Epoch 10, Acc(train/val): 5.41/3.32, Loss(train/val) 0.00225/0.00121. Took 0.53 sec
# Epoch 11, Acc(train/val): 5.37/4.27, Loss(train/val) 0.00213/0.00145. Took 0.51 sec
# Epoch 12, Acc(train/val): 5.25/6.34, Loss(train/val) 0.00212/0.00319. Took 0.53 sec
# Epoch 13, Acc(train/val): 5.84/5.01, Loss(train/val) 0.00233/0.00189. Took 0.51 sec
# Epoch 14, Acc(train/val): 5.97/9.32, Loss(train/val) 0.00241/0.00657. Took 0.53 sec
# Epoch 15, Acc(train/val): 6.32/13.57, Loss(train/val) 0.00258/0.00843. Took 0.52 sec
# Epoch 16, Acc(train/val): 5.41/4.22, Loss(train/val) 0.00228/0.00229. Took 0.54 sec
# Epoch 17, Acc(train/val): 5.65/2.70, Loss(train/val) 0.00232/0.00093. Took 0.52 sec
# Epoch 18, Acc(train/val): 5.23/4.88, Loss(train/val) 0.00206/0.00180. Took 0.53 sec
# Epoch 19, Acc(train/val): 4.41/1.77, Loss(train/val) 0.00174/0.00060. Took 0.52 sec
# Epoch 20, Acc(train/val): 4.80/4.92, Loss(train/val) 0.00194/0.00199. Took 0.53 sec
# Epoch 21, Acc(train/val): 5.67/5.77, Loss(train/val) 0.00221/0.00307. Took 0.52 sec
# Epoch 22, Acc(train/val): 5.08/2.76, Loss(train/val) 0.00208/0.00105. Took 0.52 sec
# Epoch 23, Acc(train/val): 4.88/3.08, Loss(train/val) 0.00189/0.00092. Took 0.51 sec
# Epoch 24, Acc(train/val): 4.48/4.53, Loss(train/val) 0.00178/0.00183. Took 0.52 sec
# Epoch 25, Acc(train/val): 4.87/2.07, Loss(train/val) 0.00194/0.00075. Took 0.51 sec
# Epoch 26, Acc(train/val): 4.78/3.60, Loss(train/val) 0.00191/0.00117. Took 0.51 sec
# Epoch 27, Acc(train/val): 5.29/3.11, Loss(train/val) 0.00216/0.00112. Took 0.51 sec
# Epoch 28, Acc(train/val): 4.73/4.75, Loss(train/val) 0.00196/0.00210. Took 0.53 sec
# Epoch 29, Acc(train/val): 4.83/2.68, Loss(train/val) 0.00191/0.00082. Took 0.51 sec
# len: 2215
# Epoch 0, Acc(train/val): 9.04/18.69, Loss(train/val) 0.00614/0.01997. Took 0.53 sec
# Epoch 1, Acc(train/val): 5.16/4.79, Loss(train/val) 0.00230/0.00180. Took 0.51 sec
# Epoch 2, Acc(train/val): 5.26/3.72, Loss(train/val) 0.00241/0.00141. Took 0.52 sec
# Epoch 3, Acc(train/val): 4.24/4.21, Loss(train/val) 0.00180/0.00167. Took 0.51 sec
# Epoch 4, Acc(train/val): 5.12/4.06, Loss(train/val) 0.00220/0.00132. Took 0.52 sec
# Epoch 5, Acc(train/val): 4.95/3.04, Loss(train/val) 0.00230/0.00097. Took 0.51 sec
# Epoch 6, Acc(train/val): 4.55/3.68, Loss(train/val) 0.00201/0.00146. Took 0.52 sec
# Epoch 7, Acc(train/val): 4.28/3.76, Loss(train/val) 0.00178/0.00108. Took 0.50 sec
# Epoch 8, Acc(train/val): 4.90/4.90, Loss(train/val) 0.00197/0.00160. Took 0.51 sec
# Epoch 9, Acc(train/val): 4.34/5.85, Loss(train/val) 0.00174/0.00242. Took 0.50 sec
# Epoch 10, Acc(train/val): 4.58/6.74, Loss(train/val) 0.00192/0.00307. Took 0.51 sec
# Best model saved
# Epoch 11, Acc(train/val): 4.03/1.74, Loss(train/val) 0.00164/0.00063. Took 0.51 sec
# Epoch 12, Acc(train/val): 4.41/5.67, Loss(train/val) 0.00188/0.00230. Took 0.52 sec
# Epoch 13, Acc(train/val): 4.84/2.15, Loss(train/val) 0.00213/0.00074. Took 0.51 sec
# Epoch 14, Acc(train/val): 5.02/1.86, Loss(train/val) 0.00225/0.00074. Took 0.52 sec
# Epoch 15, Acc(train/val): 6.49/5.66, Loss(train/val) 0.00300/0.00384. Took 0.52 sec
# Epoch 16, Acc(train/val): 6.28/7.41, Loss(train/val) 0.00275/0.00357. Took 0.52 sec
# Epoch 17, Acc(train/val): 4.91/5.86, Loss(train/val) 0.00195/0.00240. Took 0.52 sec
# Epoch 18, Acc(train/val): 4.46/5.14, Loss(train/val) 0.00181/0.00227. Took 0.53 sec
# Epoch 19, Acc(train/val): 3.81/2.07, Loss(train/val) 0.00162/0.00066. Took 0.52 sec
# Epoch 20, Acc(train/val): 4.51/2.30, Loss(train/val) 0.00184/0.00079. Took 0.52 sec
# Epoch 21, Acc(train/val): 4.50/4.39, Loss(train/val) 0.00184/0.00143. Took 0.53 sec
# Epoch 22, Acc(train/val): 4.78/2.14, Loss(train/val) 0.00199/0.00075. Took 0.51 sec
# Epoch 23, Acc(train/val): 4.39/5.60, Loss(train/val) 0.00177/0.00218. Took 0.55 sec
# Epoch 24, Acc(train/val): 4.43/3.82, Loss(train/val) 0.00174/0.00118. Took 0.51 sec
# Epoch 25, Acc(train/val): 4.53/1.98, Loss(train/val) 0.00178/0.00063. Took 0.55 sec
# Epoch 26, Acc(train/val): 4.10/2.17, Loss(train/val) 0.00168/0.00072. Took 0.51 sec
# Epoch 27, Acc(train/val): 4.55/3.81, Loss(train/val) 0.00193/0.00093. Took 0.53 sec
# Epoch 28, Acc(train/val): 4.23/2.87, Loss(train/val) 0.00171/0.00082. Took 0.54 sec
# Epoch 29, Acc(train/val): 4.38/7.35, Loss(train/val) 0.00182/0.00420. Took 0.52 sec
# len: 2215
# Epoch 0, Acc(train/val): 4.90/7.17, Loss(train/val) 0.00205/0.00369. Took 0.52 sec
# Epoch 1, Acc(train/val): 4.55/6.00, Loss(train/val) 0.00195/0.00352. Took 0.53 sec
# Epoch 2, Acc(train/val): 4.27/6.05, Loss(train/val) 0.00169/0.00357. Took 0.52 sec
# Epoch 3, Acc(train/val): 4.47/3.27, Loss(train/val) 0.00196/0.00120. Took 0.52 sec
# Epoch 4, Acc(train/val): 4.02/5.40, Loss(train/val) 0.00164/0.00252. Took 0.51 sec
# Epoch 5, Acc(train/val): 5.19/4.28, Loss(train/val) 0.00223/0.00174. Took 0.52 sec
# Epoch 6, Acc(train/val): 4.11/9.93, Loss(train/val) 0.00171/0.00545. Took 0.52 sec
# Epoch 7, Acc(train/val): 4.11/6.34, Loss(train/val) 0.00164/0.00386. Took 0.53 sec
# Epoch 8, Acc(train/val): 4.54/5.38, Loss(train/val) 0.00187/0.00287. Took 0.54 sec
# Epoch 9, Acc(train/val): 4.87/6.06, Loss(train/val) 0.00210/0.00333. Took 0.52 sec
# Epoch 10, Acc(train/val): 4.47/4.55, Loss(train/val) 0.00183/0.00174. Took 0.53 sec
# Epoch 11, Acc(train/val): 4.03/5.64, Loss(train/val) 0.00160/0.00218. Took 0.51 sec
# Epoch 12, Acc(train/val): 4.55/4.37, Loss(train/val) 0.00173/0.00153. Took 0.53 sec
# Epoch 13, Acc(train/val): 4.98/8.15, Loss(train/val) 0.00200/0.00349. Took 0.51 sec
# Epoch 14, Acc(train/val): 4.40/1.99, Loss(train/val) 0.00181/0.00068. Took 0.51 sec
# Epoch 15, Acc(train/val): 4.02/7.72, Loss(train/val) 0.00156/0.00532. Took 0.51 sec
# Epoch 16, Acc(train/val): 4.69/8.29, Loss(train/val) 0.00201/0.00430. Took 0.54 sec
# Epoch 17, Acc(train/val): 4.94/5.61, Loss(train/val) 0.00214/0.00255. Took 0.52 sec
# Epoch 18, Acc(train/val): 5.28/13.83, Loss(train/val) 0.00223/0.01814. Took 0.52 sec
# Epoch 19, Acc(train/val): 5.26/4.08, Loss(train/val) 0.00225/0.00164. Took 0.52 sec
# Epoch 20, Acc(train/val): 4.73/8.51, Loss(train/val) 0.00195/0.00380. Took 0.52 sec
# Epoch 21, Acc(train/val): 4.32/4.21, Loss(train/val) 0.00174/0.00174. Took 0.52 sec
# Epoch 22, Acc(train/val): 4.49/3.87, Loss(train/val) 0.00180/0.00144. Took 0.52 sec
# Epoch 23, Acc(train/val): 4.35/8.72, Loss(train/val) 0.00176/0.00645. Took 0.52 sec
# Epoch 24, Acc(train/val): 4.83/9.46, Loss(train/val) 0.00197/0.00514. Took 0.52 sec
# Epoch 25, Acc(train/val): 4.02/5.05, Loss(train/val) 0.00161/0.00223. Took 0.52 sec
# Epoch 26, Acc(train/val): 4.43/4.75, Loss(train/val) 0.00178/0.00200. Took 0.52 sec
# Epoch 27, Acc(train/val): 4.36/4.63, Loss(train/val) 0.00178/0.00205. Took 0.51 sec
# Epoch 28, Acc(train/val): 4.16/1.81, Loss(train/val) 0.00167/0.00061. Took 0.54 sec
# Epoch 29, Acc(train/val): 4.11/3.53, Loss(train/val) 0.00169/0.00135. Took 0.51 sec
# len: 2215
# Epoch 0, Acc(train/val): 5.27/5.94, Loss(train/val) 0.00243/0.00425. Took 0.52 sec
# Epoch 1, Acc(train/val): 3.73/3.56, Loss(train/val) 0.00158/0.00141. Took 0.52 sec
# Epoch 2, Acc(train/val): 3.60/4.85, Loss(train/val) 0.00142/0.00206. Took 0.52 sec
# Epoch 3, Acc(train/val): 3.98/3.49, Loss(train/val) 0.00163/0.00108. Took 0.52 sec
# Epoch 4, Acc(train/val): 3.70/4.40, Loss(train/val) 0.00152/0.00180. Took 0.52 sec
# Epoch 5, Acc(train/val): 3.42/13.39, Loss(train/val) 0.00132/0.00902. Took 0.53 sec
# Epoch 6, Acc(train/val): 4.87/9.90, Loss(train/val) 0.00219/0.00597. Took 0.53 sec
# Epoch 7, Acc(train/val): 3.47/7.57, Loss(train/val) 0.00144/0.00497. Took 0.54 sec
# Best model saved
# Epoch 8, Acc(train/val): 3.70/1.58, Loss(train/val) 0.00156/0.00048. Took 0.51 sec
# Epoch 9, Acc(train/val): 3.40/3.08, Loss(train/val) 0.00141/0.00100. Took 0.53 sec
# Epoch 10, Acc(train/val): 4.17/1.60, Loss(train/val) 0.00174/0.00055. Took 0.50 sec
# Epoch 11, Acc(train/val): 3.70/6.97, Loss(train/val) 0.00144/0.00336. Took 0.53 sec
# Epoch 12, Acc(train/val): 4.25/4.71, Loss(train/val) 0.00174/0.00192. Took 0.51 sec
# Epoch 13, Acc(train/val): 3.62/5.31, Loss(train/val) 0.00146/0.00227. Took 0.53 sec
# Best model saved
# Epoch 14, Acc(train/val): 4.45/1.50, Loss(train/val) 0.00176/0.00061. Took 0.52 sec
# Epoch 15, Acc(train/val): 3.35/3.72, Loss(train/val) 0.00133/0.00150. Took 0.52 sec
# Epoch 16, Acc(train/val): 3.46/4.12, Loss(train/val) 0.00136/0.00140. Took 0.51 sec
# Epoch 17, Acc(train/val): 4.11/4.06, Loss(train/val) 0.00165/0.00187. Took 0.53 sec
# Epoch 18, Acc(train/val): 3.64/4.27, Loss(train/val) 0.00152/0.00222. Took 0.52 sec
# Epoch 19, Acc(train/val): 3.75/2.75, Loss(train/val) 0.00155/0.00100. Took 0.53 sec
# Epoch 20, Acc(train/val): 3.83/2.75, Loss(train/val) 0.00147/0.00087. Took 0.51 sec
# Epoch 21, Acc(train/val): 3.76/6.84, Loss(train/val) 0.00147/0.00245. Took 0.51 sec
# Epoch 22, Acc(train/val): 3.64/1.90, Loss(train/val) 0.00146/0.00066. Took 0.51 sec
# Epoch 23, Acc(train/val): 3.36/4.04, Loss(train/val) 0.00137/0.00150. Took 0.52 sec
# Epoch 24, Acc(train/val): 3.69/5.19, Loss(train/val) 0.00147/0.00186. Took 0.54 sec
# Epoch 25, Acc(train/val): 3.51/1.91, Loss(train/val) 0.00137/0.00067. Took 0.53 sec
# Epoch 26, Acc(train/val): 3.94/3.60, Loss(train/val) 0.00155/0.00133. Took 0.51 sec
# Epoch 27, Acc(train/val): 3.59/2.35, Loss(train/val) 0.00143/0.00078. Took 0.51 sec
# Epoch 28, Acc(train/val): 3.40/4.56, Loss(train/val) 0.00129/0.00171. Took 0.53 sec
# Epoch 29, Acc(train/val): 3.67/2.77, Loss(train/val) 0.00143/0.00092. Took 0.53 sec
# len: 2215
# Epoch 0, Acc(train/val): 4.66/4.29, Loss(train/val) 0.00228/0.00244. Took 0.53 sec
# Epoch 1, Acc(train/val): 3.69/4.23, Loss(train/val) 0.00184/0.00171. Took 0.52 sec
# Epoch 2, Acc(train/val): 3.20/3.66, Loss(train/val) 0.00156/0.00168. Took 0.54 sec
# Epoch 3, Acc(train/val): 3.94/5.49, Loss(train/val) 0.00191/0.00297. Took 0.51 sec
# Epoch 4, Acc(train/val): 3.57/5.59, Loss(train/val) 0.00171/0.00276. Took 0.53 sec
# Epoch 5, Acc(train/val): 3.80/7.82, Loss(train/val) 0.00185/0.00631. Took 0.51 sec
# Epoch 6, Acc(train/val): 4.08/6.62, Loss(train/val) 0.00191/0.00266. Took 0.53 sec
# Epoch 7, Acc(train/val): 4.16/5.08, Loss(train/val) 0.00199/0.00228. Took 0.51 sec
# Epoch 8, Acc(train/val): 3.86/2.67, Loss(train/val) 0.00179/0.00107. Took 0.53 sec
# Epoch 9, Acc(train/val): 3.60/2.19, Loss(train/val) 0.00173/0.00089. Took 0.51 sec
# Epoch 10, Acc(train/val): 4.77/1.59, Loss(train/val) 0.00245/0.00070. Took 0.54 sec
# Epoch 11, Acc(train/val): 3.95/3.58, Loss(train/val) 0.00198/0.00175. Took 0.52 sec
# Epoch 12, Acc(train/val): 3.43/6.86, Loss(train/val) 0.00170/0.00348. Took 0.53 sec
# Epoch 13, Acc(train/val): 3.76/2.56, Loss(train/val) 0.00178/0.00116. Took 0.51 sec
# Epoch 14, Acc(train/val): 3.78/11.66, Loss(train/val) 0.00173/0.00688. Took 0.53 sec
# Epoch 15, Acc(train/val): 3.88/2.92, Loss(train/val) 0.00177/0.00128. Took 0.52 sec
# Epoch 16, Acc(train/val): 3.84/4.17, Loss(train/val) 0.00180/0.00184. Took 0.54 sec
# Epoch 17, Acc(train/val): 3.89/9.56, Loss(train/val) 0.00191/0.00576. Took 0.51 sec
# Epoch 18, Acc(train/val): 3.96/3.50, Loss(train/val) 0.00195/0.00153. Took 0.52 sec
# Epoch 19, Acc(train/val): 3.30/4.49, Loss(train/val) 0.00161/0.00197. Took 0.52 sec
# Epoch 20, Acc(train/val): 3.78/7.84, Loss(train/val) 0.00176/0.00436. Took 0.52 sec
# Epoch 21, Acc(train/val): 3.68/4.39, Loss(train/val) 0.00173/0.00201. Took 0.53 sec
# Epoch 22, Acc(train/val): 3.73/4.49, Loss(train/val) 0.00176/0.00191. Took 0.52 sec
# Epoch 23, Acc(train/val): 3.85/5.57, Loss(train/val) 0.00187/0.00282. Took 0.51 sec
# Epoch 24, Acc(train/val): 4.02/5.93, Loss(train/val) 0.00194/0.00285. Took 0.51 sec
# Epoch 25, Acc(train/val): 4.00/3.21, Loss(train/val) 0.00191/0.00128. Took 0.51 sec
# Epoch 26, Acc(train/val): 3.55/3.75, Loss(train/val) 0.00171/0.00162. Took 0.52 sec
# Epoch 27, Acc(train/val): 3.81/8.66, Loss(train/val) 0.00181/0.00433. Took 0.51 sec
# Epoch 28, Acc(train/val): 3.82/3.37, Loss(train/val) 0.00174/0.00139. Took 0.52 sec
# Epoch 29, Acc(train/val): 4.03/4.84, Loss(train/val) 0.00195/0.00194. Took 0.53 sec
# len: 2215
# Epoch 0, Acc(train/val): 9.28/26.73, Loss(train/val) 0.00555/0.03273. Took 0.52 sec
# Epoch 1, Acc(train/val): 6.59/11.90, Loss(train/val) 0.00278/0.00737. Took 0.51 sec
# Epoch 2, Acc(train/val): 7.08/8.93, Loss(train/val) 0.00320/0.00640. Took 0.51 sec
# Epoch 3, Acc(train/val): 6.09/8.73, Loss(train/val) 0.00256/0.00639. Took 0.53 sec
# Epoch 4, Acc(train/val): 5.21/7.64, Loss(train/val) 0.00208/0.00321. Took 0.52 sec
# Epoch 5, Acc(train/val): 5.16/5.49, Loss(train/val) 0.00199/0.00230. Took 0.51 sec
# Epoch 6, Acc(train/val): 4.67/4.54, Loss(train/val) 0.00180/0.00196. Took 0.53 sec
# Epoch 7, Acc(train/val): 4.74/6.06, Loss(train/val) 0.00185/0.00287. Took 0.51 sec
# Epoch 8, Acc(train/val): 4.73/4.80, Loss(train/val) 0.00179/0.00196. Took 0.52 sec
# Epoch 9, Acc(train/val): 6.06/6.52, Loss(train/val) 0.00232/0.00343. Took 0.52 sec
# Epoch 10, Acc(train/val): 4.80/5.91, Loss(train/val) 0.00182/0.00313. Took 0.53 sec
# Epoch 11, Acc(train/val): 4.66/3.49, Loss(train/val) 0.00185/0.00117. Took 0.51 sec
# Epoch 12, Acc(train/val): 4.68/2.41, Loss(train/val) 0.00184/0.00077. Took 0.52 sec
# Epoch 13, Acc(train/val): 4.72/3.09, Loss(train/val) 0.00176/0.00107. Took 0.52 sec
# Epoch 14, Acc(train/val): 4.71/3.54, Loss(train/val) 0.00169/0.00117. Took 0.51 sec
# Epoch 15, Acc(train/val): 4.41/5.99, Loss(train/val) 0.00171/0.00292. Took 0.51 sec
# Epoch 16, Acc(train/val): 4.49/5.51, Loss(train/val) 0.00168/0.00200. Took 0.52 sec
# Epoch 17, Acc(train/val): 4.31/3.41, Loss(train/val) 0.00152/0.00122. Took 0.52 sec
# Epoch 18, Acc(train/val): 3.68/5.15, Loss(train/val) 0.00134/0.00220. Took 0.52 sec
# Epoch 19, Acc(train/val): 4.83/2.67, Loss(train/val) 0.00170/0.00084. Took 0.52 sec
# Epoch 20, Acc(train/val): 3.88/3.83, Loss(train/val) 0.00144/0.00139. Took 0.51 sec
# Epoch 21, Acc(train/val): 4.42/4.63, Loss(train/val) 0.00164/0.00172. Took 0.52 sec
# Epoch 22, Acc(train/val): 4.24/6.73, Loss(train/val) 0.00158/0.00383. Took 0.52 sec
# Epoch 23, Acc(train/val): 4.39/4.17, Loss(train/val) 0.00164/0.00145. Took 0.52 sec
# Epoch 24, Acc(train/val): 4.43/4.54, Loss(train/val) 0.00166/0.00170. Took 0.51 sec
# Epoch 25, Acc(train/val): 3.80/3.01, Loss(train/val) 0.00143/0.00097. Took 0.52 sec
# Epoch 26, Acc(train/val): 4.37/3.76, Loss(train/val) 0.00161/0.00129. Took 0.51 sec
# Epoch 27, Acc(train/val): 4.57/4.30, Loss(train/val) 0.00168/0.00162. Took 0.52 sec
# Epoch 28, Acc(train/val): 4.53/5.36, Loss(train/val) 0.00177/0.00210. Took 0.52 sec
# Epoch 29, Acc(train/val): 4.43/5.50, Loss(train/val) 0.00167/0.00211. Took 0.52 sec
# len: 2215
# Epoch 0, Acc(train/val): 7.43/6.53, Loss(train/val) 0.00499/0.00416. Took 0.51 sec
# Epoch 1, Acc(train/val): 5.21/4.67, Loss(train/val) 0.00279/0.00200. Took 0.53 sec
# Epoch 2, Acc(train/val): 4.04/3.36, Loss(train/val) 0.00208/0.00130. Took 0.51 sec
# Epoch 3, Acc(train/val): 3.98/3.36, Loss(train/val) 0.00207/0.00148. Took 0.53 sec
# Epoch 4, Acc(train/val): 3.48/1.68, Loss(train/val) 0.00185/0.00061. Took 0.50 sec
# Epoch 5, Acc(train/val): 3.75/3.28, Loss(train/val) 0.00196/0.00127. Took 0.52 sec
# Epoch 6, Acc(train/val): 3.64/3.00, Loss(train/val) 0.00187/0.00103. Took 0.53 sec
# Epoch 7, Acc(train/val): 4.24/3.90, Loss(train/val) 0.00213/0.00129. Took 0.53 sec
# Epoch 8, Acc(train/val): 3.89/5.91, Loss(train/val) 0.00199/0.00215. Took 0.51 sec
# Epoch 9, Acc(train/val): 4.02/2.27, Loss(train/val) 0.00198/0.00069. Took 0.52 sec
# Epoch 10, Acc(train/val): 4.33/5.25, Loss(train/val) 0.00216/0.00250. Took 0.50 sec
# Epoch 11, Acc(train/val): 4.39/6.50, Loss(train/val) 0.00231/0.00403. Took 0.52 sec
# Epoch 12, Acc(train/val): 3.55/2.33, Loss(train/val) 0.00186/0.00083. Took 0.51 sec
# Epoch 13, Acc(train/val): 3.73/2.84, Loss(train/val) 0.00188/0.00096. Took 0.52 sec
# Epoch 14, Acc(train/val): 3.49/1.56, Loss(train/val) 0.00179/0.00057. Took 0.50 sec
# Epoch 15, Acc(train/val): 3.73/2.25, Loss(train/val) 0.00192/0.00070. Took 0.51 sec
# Epoch 16, Acc(train/val): 3.78/2.60, Loss(train/val) 0.00193/0.00088. Took 0.50 sec
# Epoch 17, Acc(train/val): 3.87/3.90, Loss(train/val) 0.00193/0.00143. Took 0.52 sec
# Epoch 18, Acc(train/val): 4.01/4.10, Loss(train/val) 0.00204/0.00150. Took 0.51 sec
# Epoch 19, Acc(train/val): 4.23/3.38, Loss(train/val) 0.00212/0.00127. Took 0.52 sec
# Epoch 20, Acc(train/val): 3.29/2.40, Loss(train/val) 0.00171/0.00077. Took 0.50 sec
# Epoch 21, Acc(train/val): 3.40/3.05, Loss(train/val) 0.00178/0.00103. Took 0.51 sec
# Epoch 22, Acc(train/val): 3.20/1.91, Loss(train/val) 0.00166/0.00064. Took 0.52 sec
# Epoch 23, Acc(train/val): 4.07/1.89, Loss(train/val) 0.00202/0.00063. Took 0.53 sec
# Epoch 24, Acc(train/val): 4.14/3.69, Loss(train/val) 0.00214/0.00136. Took 0.51 sec
# Epoch 25, Acc(train/val): 3.88/3.53, Loss(train/val) 0.00195/0.00111. Took 0.51 sec
# Epoch 26, Acc(train/val): 3.72/2.92, Loss(train/val) 0.00191/0.00118. Took 0.53 sec
# Epoch 27, Acc(train/val): 3.71/4.31, Loss(train/val) 0.00181/0.00160. Took 0.52 sec
# Epoch 28, Acc(train/val): 3.61/2.08, Loss(train/val) 0.00181/0.00067. Took 0.52 sec
# Epoch 29, Acc(train/val): 3.78/1.78, Loss(train/val) 0.00194/0.00064. Took 0.51 sec
# len: 2215
# Epoch 0, Acc(train/val): 4.52/7.30, Loss(train/val) 0.00294/0.00437. Took 0.51 sec
# Epoch 1, Acc(train/val): 4.62/5.43, Loss(train/val) 0.00295/0.00298. Took 0.51 sec
# Epoch 2, Acc(train/val): 3.73/3.79, Loss(train/val) 0.00257/0.00153. Took 0.51 sec
# Epoch 3, Acc(train/val): 3.97/2.38, Loss(train/val) 0.00265/0.00094. Took 0.52 sec
# Epoch 4, Acc(train/val): 3.84/1.72, Loss(train/val) 0.00253/0.00057. Took 0.51 sec
# Epoch 5, Acc(train/val): 3.98/6.89, Loss(train/val) 0.00272/0.00314. Took 0.51 sec
# Epoch 6, Acc(train/val): 3.70/3.74, Loss(train/val) 0.00256/0.00185. Took 0.51 sec
# Epoch 7, Acc(train/val): 3.73/2.81, Loss(train/val) 0.00259/0.00147. Took 0.52 sec
# Epoch 8, Acc(train/val): 3.60/5.00, Loss(train/val) 0.00251/0.00223. Took 0.52 sec
# Epoch 9, Acc(train/val): 3.75/4.81, Loss(train/val) 0.00256/0.00257. Took 0.52 sec
# Epoch 10, Acc(train/val): 4.07/3.24, Loss(train/val) 0.00269/0.00159. Took 0.51 sec
# Epoch 11, Acc(train/val): 3.60/2.64, Loss(train/val) 0.00249/0.00168. Took 0.51 sec
# Epoch 12, Acc(train/val): 3.70/3.82, Loss(train/val) 0.00253/0.00226. Took 0.51 sec
# Epoch 13, Acc(train/val): 3.81/2.84, Loss(train/val) 0.00256/0.00148. Took 0.53 sec
# Epoch 14, Acc(train/val): 3.59/2.23, Loss(train/val) 0.00246/0.00135. Took 0.51 sec
# Epoch 15, Acc(train/val): 4.01/4.05, Loss(train/val) 0.00262/0.00228. Took 0.51 sec
# Epoch 16, Acc(train/val): 3.92/3.12, Loss(train/val) 0.00259/0.00137. Took 0.51 sec
# Epoch 17, Acc(train/val): 3.68/2.73, Loss(train/val) 0.00252/0.00176. Took 0.51 sec
# Epoch 18, Acc(train/val): 3.61/3.15, Loss(train/val) 0.00245/0.00130. Took 0.52 sec
# Epoch 19, Acc(train/val): 4.08/5.38, Loss(train/val) 0.00272/0.00325. Took 0.52 sec
# Epoch 20, Acc(train/val): 4.27/4.55, Loss(train/val) 0.00281/0.00265. Took 0.51 sec
# Epoch 21, Acc(train/val): 4.09/4.11, Loss(train/val) 0.00277/0.00128. Took 0.52 sec
# Epoch 22, Acc(train/val): 3.91/3.58, Loss(train/val) 0.00255/0.00172. Took 0.50 sec
# Epoch 23, Acc(train/val): 4.16/4.31, Loss(train/val) 0.00274/0.00249. Took 0.52 sec
# Epoch 24, Acc(train/val): 3.94/5.35, Loss(train/val) 0.00263/0.00320. Took 0.52 sec
# Epoch 25, Acc(train/val): 3.93/2.67, Loss(train/val) 0.00259/0.00164. Took 0.51 sec
# Epoch 26, Acc(train/val): 3.58/3.77, Loss(train/val) 0.00242/0.00216. Took 0.53 sec
# Epoch 27, Acc(train/val): 3.82/2.24, Loss(train/val) 0.00259/0.00119. Took 0.55 sec
# Epoch 28, Acc(train/val): 3.77/2.82, Loss(train/val) 0.00254/0.00162. Took 0.52 sec
# Epoch 29, Acc(train/val): 3.67/3.65, Loss(train/val) 0.00248/0.00194. Took 0.52 sec
# len: 2215
# Epoch 0, Acc(train/val): 4.86/4.37, Loss(train/val) 0.00210/0.00135. Took 0.52 sec
# Epoch 1, Acc(train/val): 3.56/2.00, Loss(train/val) 0.00138/0.00067. Took 0.52 sec
# Epoch 2, Acc(train/val): 3.56/2.99, Loss(train/val) 0.00139/0.00104. Took 0.51 sec
# Epoch 3, Acc(train/val): 4.14/2.75, Loss(train/val) 0.00161/0.00095. Took 0.54 sec
# Epoch 4, Acc(train/val): 4.14/1.65, Loss(train/val) 0.00169/0.00062. Took 0.52 sec
# Epoch 5, Acc(train/val): 3.77/3.65, Loss(train/val) 0.00150/0.00125. Took 0.51 sec
# Epoch 6, Acc(train/val): 3.91/2.63, Loss(train/val) 0.00155/0.00099. Took 0.52 sec
# Epoch 7, Acc(train/val): 3.80/3.53, Loss(train/val) 0.00147/0.00128. Took 0.52 sec
# Epoch 8, Acc(train/val): 3.38/3.79, Loss(train/val) 0.00126/0.00150. Took 0.52 sec
# Epoch 9, Acc(train/val): 3.69/2.23, Loss(train/val) 0.00139/0.00072. Took 0.52 sec
# Epoch 10, Acc(train/val): 3.74/3.33, Loss(train/val) 0.00147/0.00126. Took 0.51 sec
# Epoch 11, Acc(train/val): 3.71/4.42, Loss(train/val) 0.00141/0.00182. Took 0.52 sec
# Epoch 12, Acc(train/val): 4.16/3.57, Loss(train/val) 0.00167/0.00134. Took 0.50 sec
# Epoch 13, Acc(train/val): 3.70/3.06, Loss(train/val) 0.00148/0.00092. Took 0.51 sec
# Epoch 14, Acc(train/val): 3.89/3.76, Loss(train/val) 0.00152/0.00142. Took 0.51 sec
# Epoch 15, Acc(train/val): 3.46/2.14, Loss(train/val) 0.00129/0.00062. Took 0.57 sec
# Epoch 16, Acc(train/val): 3.56/1.57, Loss(train/val) 0.00137/0.00059. Took 0.54 sec
# Epoch 17, Acc(train/val): 4.10/5.79, Loss(train/val) 0.00161/0.00274. Took 0.55 sec
# Epoch 18, Acc(train/val): 3.73/2.18, Loss(train/val) 0.00144/0.00060. Took 0.52 sec
# Epoch 19, Acc(train/val): 3.90/5.45, Loss(train/val) 0.00150/0.00239. Took 0.54 sec
# Epoch 20, Acc(train/val): 4.24/8.94, Loss(train/val) 0.00173/0.00527. Took 0.52 sec
# Epoch 21, Acc(train/val): 3.99/5.11, Loss(train/val) 0.00159/0.00242. Took 0.53 sec
# Epoch 22, Acc(train/val): 3.55/3.45, Loss(train/val) 0.00136/0.00134. Took 0.52 sec
# Epoch 23, Acc(train/val): 3.76/3.24, Loss(train/val) 0.00154/0.00111. Took 0.53 sec
# Epoch 24, Acc(train/val): 3.50/3.27, Loss(train/val) 0.00132/0.00115. Took 0.53 sec
# Epoch 25, Acc(train/val): 3.39/2.38, Loss(train/val) 0.00124/0.00086. Took 0.54 sec
# Epoch 26, Acc(train/val): 3.94/4.19, Loss(train/val) 0.00156/0.00151. Took 0.52 sec
# Epoch 27, Acc(train/val): 4.61/2.26, Loss(train/val) 0.00187/0.00083. Took 0.52 sec
# Epoch 28, Acc(train/val): 3.75/3.35, Loss(train/val) 0.00144/0.00112. Took 0.54 sec
# Epoch 29, Acc(train/val): 4.03/2.34, Loss(train/val) 0.00153/0.00082. Took 0.52 sec

# %%
testinput = StockDataset('028050',args.x_frames,args.y_frames,(2001,1,1),(2020,5,13))
testloader = DataLoader(testinput, batch_size=args.batch_size, shuffle=False, drop_last=True)

print(len(testloader))
# Out:
# len: 4784
# 37

# %%
result = []
result2 = []
for i, (X,y) in enumerate(testloader):

    model.eval()
    X = X.transpose(0, 1).float().to(args.device)
    y_true = y[:, :, 3].float().to(args.device)

    y_pred = model(X)
    y_pred = y_pred.view(-1)
    y_true = y_true.view(-1)
    y_pred = y_pred.cpu().detach().numpy()
    y_true = y_true.cpu().detach().numpy()
    result.extend(y_pred)
    result2.extend(y_true)

# %%
best_model.load_state_dict(torch.load('/content/gdrive/My Drive/GRUmodel/GRU_Best_model.pt'))
best_model.to(args.device)
result3 = []
for i, (X,y) in enumerate(testloader):

    best_model.eval()
    X = X.transpose(0, 1).float().to(args.device)
    y_true = y[:, :, 3].float().to(args.device)

    y_pred = best_model(X)
    y_pred = y_pred.view(-1)
    y_true = y_true.view(-1)
    y_pred = y_pred.cpu().detach().numpy()
    result3.extend(y_pred)

# %%
model == best_model
# Out:
# False

# %%
fig = plt.figure(figsize=(40,10))
xl = [n for n in range(1,len(result)+1)]


# ====== test plot ====== #
ax = fig.add_subplot(1, 1, 1)
ax.plot(xl, result,  label='pred')
ax.plot(xl, result2,  label='real')
ax.plot(xl, result3,  label='pred_best')
ax.set_xlabel('len')
ax.set_ylabel('value')
ax.grid()
ax.legend()
ax.set_title('pred vs real')
# Out:
# Text(0.5, 1.0, 'pred vs real')

# %%
'''
from google.colab import drive
drive.mount('/content/gdrive')

modelPath = '/content/gdrive/My Drive/GRU_batch_128_model.pt'
torch.save(model.state_dict(), modelPath)
'''
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/gdrive')\n\nmodelPath = '/content/gdrive/My Drive/GRU_batch_128_model.pt'\ntorch.save(model.state_dict(), modelPath)\n"
